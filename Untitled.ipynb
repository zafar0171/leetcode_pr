# %%
import os

# %%
print(os.getenv('HOME'))
# Out:
# None

# %%
os.getcwd()
# Out:
# 'C:\\Users\\modza\\Documents\\leetcode'

# %%
os.get_exec_path()
# Out:
# ['c:\\users\\modza\\documents\\leetcode\\venv',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\mingw-w64\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\usr\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Scripts',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\bin',
#  'c:\\ProgramData\\miniconda3\\condabin',
#  'C:\\Program Files\\Microsoft SDKs\\Azure\\CLI2\\wbin',
#  'C:\\Program Files\\FFmpeg\\bin',
#  'C:\\Program Files\\eSpeak NG',
#  'C:\\Users\\modza\\AppData\\Roaming\\python\\Python39\\Scripts',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\bin',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\libnvvp',
#  'c:\\Users\\modza\\AppData\\Local\\Programs\\cursor\\resources\\app\\bin',
#  'C:\\Windows\\system32',
#  'C:\\Windows',
#  'C:\\Windows\\System32\\Wbem',
#  'C:\\Windows\\System32\\WindowsPowerShell\\v1.0',
# ...

# %%
os.process_cpu_count()
# Out:
# 8

# %%
os.getpid()
# Out:
# 7740

# %%
os.getlogin()
# Out:
# 'modza'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'bash_sc.py',
#  'file_handling.py',
#  'leetcode_pr',
#  'regex_pr.py',
#  'Untitled.ipynb',
#  'venv']

# %%
os.remove('file_handling.py')

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'bash_sc.py',
#  'leetcode_pr',
#  'regex_pr.py',
#  'Untitled.ipynb',
#  'venv']

# %%
help(os.rename)
# Out:
# Help on built-in function rename in module nt:
#
# rename(src, dst, *, src_dir_fd=None, dst_dir_fd=None)
#     Rename a file or directory.
#
#     If either src_dir_fd or dst_dir_fd is not None, it should be a file
#       descriptor open to a directory, and the respective path string (src or dst)
#       should be relative; the path will then be relative to that directory.
#     src_dir_fd and dst_dir_fd, may not be implemented on your platform.
#       If they are unavailable, using them will raise a NotImplementedError.

# %%
os.rename('Untitled.ipynb','file_handling.ipynb')

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'bash_sc.py',
#  'file_handling.ipynb',
#  'leetcode_pr',
#  'regex_pr.py',
#  'venv']

# %%
os.curdir
# Out:
# '.'

# %%
os.listdrives()
# Out:
# ['C:\\', 'D:\\', 'E:\\', 'F:\\']

# %%
os.listmounts('\\\\?\\Volume{b95172d8-12d9-44ad-a0fc-e5352f6b56e2}\\')
# Out:
# ['D:\\']

# %%
os.listvolumes()
# Out:
# ['\\\\?\\Volume{b95172d8-12d9-44ad-a0fc-e5352f6b56e2}\\',
#  '\\\\?\\Volume{72e30a10-feac-4116-832d-f6d97786c1f3}\\',
#  '\\\\?\\Volume{a9615451-52df-4d5a-99c7-965c21aa96ae}\\',
#  '\\\\?\\Volume{5ef29d42-a8ac-4bd8-85f0-d13851a3c85f}\\',
#  '\\\\?\\Volume{c53b002a-b0fa-4abd-8182-d2447214f171}\\',
#  '\\\\?\\Volume{255fa127-8f94-4181-8a63-8179ef66c640}\\']

# %%
os.getlogin()
# Out:
# 'modza'

# %%
os.startfile('cmd')

# %%
os.path.

# %%
os.startfile('Git Bash')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 os.startfile('Git Bash')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Git Bash'

# %%
os.system("open cmd")
# Out:
# 1

# %%
print(os.times())
# Out:
# nt.times_result(user=9.0, system=2.53125, children_user=0.0, children_system=0.0, elapsed=0.0)

# %%
with open('sha256sum.txt', 'r') as _f:
    for i in _f:
        print(i)

_f.close()
# Out:
# 759c9b5a2ad26eb9844b24f7da1696c705ff5fe07924a749f385f435176c2306 *linuxmint-22.2-cinnamon-64bit.iso
#
# 21f5a5f7be652c60b20ba7996328098b14e979b1ef8bf7f6c9d4a2a579504a65 *linuxmint-22.2-mate-64bit.iso
#
# dea13e523dca28e3aa48d90167a6368c63e1b3251492115417fdbf648551558f *linuxmint-22.2-xfce-64bit.iso

# %%
with open('sha256sum.txt','r') as _f:
    print(_f.readline())

_f.close()
# Out:
# 759c9b5a2ad26eb9844b24f7da1696c705ff5fe07924a749f385f435176c2306 *linuxmint-22.2-cinnamon-64bit.iso

# %%
with open('sha256sum.txt') as _f:
    print(_f.read())

_f.close()
# Out:
# 759c9b5a2ad26eb9844b24f7da1696c705ff5fe07924a749f385f435176c2306 *linuxmint-22.2-cinnamon-64bit.iso
# 21f5a5f7be652c60b20ba7996328098b14e979b1ef8bf7f6c9d4a2a579504a65 *linuxmint-22.2-mate-64bit.iso
# dea13e523dca28e3aa48d90167a6368c63e1b3251492115417fdbf648551558f *linuxmint-22.2-xfce-64bit.iso

# %%
file = open('sha256sum.txt')

# %%
file.buffer
# Out:
# <_io.BufferedReader name='sha256sum.txt'>

# %%
file.close()

# %%
with open('new.txt', 'w') as file:
    file.write("this is a new test file related to OS module use case along with other techniques")

# %%
os.remove('new_txt')

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'bash_sc.py',
#  'file_handling.ipynb',
#  'leetcode_pr',
#  'regex_pr.py',
#  'sha256sum.txt',
#  'Untitled.ipynb',
#  'venv']

# %%
print(os.open(r"C:\\users\\modza\\documents\\leetcode\\new.txt", os.O_RDONLY))
# Out:
# 4

# %%
os.path.getsize('new.txt')
# Out:
# 81

# %%
cat new.txt
# Out:
#   Cell In[72], line 1
#     cat new.txt
#         ^
# SyntaxError: invalid syntax

# %%
cat 'new.txt'
# Out:
#   Cell In[73], line 1
#     cat 'new.txt'
#         ^
# SyntaxError: invalid syntax

# %%
# %cat new.txt
# Out:
# UsageError: Line magic function `%cat` not found.

# %%
os.path.abspath('leetcode')
# Out:
# 'C:\\Users\\modza\\Documents\\leetcode\\leetcode'

# %%
direc = 'C:\\Users\\modza\\Documents\\leetcode'

for content in os.listdir(direc):

    fn = os.path.join(direc, content)
    if os.path.isdir(fn):
        print("{} is a folder".format(fn))

    else:
        print(fn)
# Out:
# C:\Users\modza\Documents\leetcode\.git is a folder
# C:\Users\modza\Documents\leetcode\.ipynb_checkpoints is a folder
# C:\Users\modza\Documents\leetcode\.venv is a folder
# C:\Users\modza\Documents\leetcode\bash_sc.py
# C:\Users\modza\Documents\leetcode\file_handling.ipynb
# C:\Users\modza\Documents\leetcode\leetcode_pr is a folder
# C:\Users\modza\Documents\leetcode\new.txt
# C:\Users\modza\Documents\leetcode\regex_pr.py
# C:\Users\modza\Documents\leetcode\sha256sum.txt
# C:\Users\modza\Documents\leetcode\Untitled.ipynb
# C:\Users\modza\Documents\leetcode\venv is a folder

# %%
for file in os.listdir:
    print(file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 for file in os.listdir:
#       2     print(file)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
import csv

# %%
with open('regex_demo.ipynb','w') as _f:
    _f.write(
        '#!/usr/bin/venv python3',
            )

# %%
os.startfile('regex_pr.py')

# %%
os.get_exec_path()
# Out:
# ['c:\\users\\modza\\documents\\leetcode\\venv',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\mingw-w64\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\usr\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Scripts',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\bin',
#  'c:\\ProgramData\\miniconda3\\condabin',
#  'C:\\Program Files\\Microsoft SDKs\\Azure\\CLI2\\wbin',
#  'C:\\Program Files\\FFmpeg\\bin',
#  'C:\\Program Files\\eSpeak NG',
#  'C:\\Users\\modza\\AppData\\Roaming\\python\\Python39\\Scripts',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\bin',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\libnvvp',
#  'c:\\Users\\modza\\AppData\\Local\\Programs\\cursor\\resources\\app\\bin',
#  'C:\\Windows\\system32',
#  'C:\\Windows',
#  'C:\\Windows\\System32\\Wbem',
#  'C:\\Windows\\System32\\WindowsPowerShell\\v1.0',
# ...

# %%
os.startfile('GitHub CLI')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 os.startfile('GitHub CLI')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'GitHub CLI'

# %%
# !nvidia-sm
# Out:
# 'nvidia-sm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !nvidia-smi
# Out:
# Sat Dec  6 22:31:11 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 546.33                 Driver Version: 546.33       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1050      WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P8              N/A /  14W |      0MiB /  3072MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\modza\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-0GENAAH',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'CONDA_BAT': 'c:\\ProgramData\\miniconda3\\condabin\\conda.bat',
#         'CONDA_DEFAULT_ENV': 'c:\\users\\modza\\documents\\leetcode\\venv',
#         'CONDA_EXE': 'c:\\ProgramData\\miniconda3\\Scripts\\conda.exe',
#         'CONDA_PREFIX': 'c:\\users\\modza\\documents\\leetcode\\venv',
#         'CONDA_PREFIX_1': 'C:\\ProgramData\\miniconda3',
#         'CONDA_PROMPT_MODIFIER': '(c:\\users\\modza\\documents\\leetcode\\venv) ',
#         'CONDA_PYTHON_EXE': 'c:\\ProgramData\\miniconda3\\python.exe',
#         'CONDA_SHLVL': '2',
# ...

# %%
os.startfile('Chrome.exe')

# %%
os.startfile('Brave.exe')

# %%
os.startfile('notepad.exe')

# %%
os.system('dir')
# Out:
# 0

# %%
os.system('listdir')
# Out:
# 1

# %%
os.system('ping www.google.com')
# Out:
# 0

# %%
import psutil

# %%
psutil.cpu_count()
# Out:
# 8

# %%
psutil.virtual_memory()
# Out:
# svmem(total=8419069952, available=1093066752, percent=87.0, used=7326003200, free=1093066752)

# %%
psutil.disk_partitions()
# Out:
# [sdiskpart(device='C:\\', mountpoint='C:\\', fstype='NTFS', opts='rw,fixed'),
#  sdiskpart(device='D:\\', mountpoint='D:\\', fstype='NTFS', opts='rw,fixed'),
#  sdiskpart(device='E:\\', mountpoint='E:\\', fstype='NTFS', opts='rw,fixed'),
#  sdiskpart(device='F:\\', mountpoint='F:\\', fstype='NTFS', opts='rw,fixed')]

# %%
os.makedirs('subset')

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'baby_products_sellers.csv',
#  'bash_sc.py',
#  'dataset_crawler-google-places_2025-12-09_07-49-09-261.csv',
#  'file_handling.ipynb',
#  'leetcode_pr',
#  'new.txt',
#  'regex_demo.ipynb',
#  'regex_pr.py',
#  'sha256sum.txt',
#  'subset',
#  'Untitled.ipynb',
#  'venv']

# %%
os.rename('subset','new_dir_sub')

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'baby_products_sellers.csv',
#  'bash_sc.py',
#  'dataset_crawler-google-places_2025-12-09_07-49-09-261.csv',
#  'file_handling.ipynb',
#  'leetcode_pr',
#  'new.txt',
#  'new_dir_sub',
#  'regex_demo.ipynb',
#  'regex_pr.py',
#  'sha256sum.txt',
#  'Untitled.ipynb',
#  'venv']

# %%
os.startfile('
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\modza\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-0GENAAH',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'CONDA_BAT': 'c:\\ProgramData\\miniconda3\\condabin\\conda.bat',
#         'CONDA_DEFAULT_ENV': 'c:\\users\\modza\\documents\\leetcode\\venv',
#         'CONDA_EXE': 'c:\\ProgramData\\miniconda3\\Scripts\\conda.exe',
#         'CONDA_PREFIX': 'c:\\users\\modza\\documents\\leetcode\\venv',
#         'CONDA_PREFIX_1': 'C:\\ProgramData\\miniconda3',
#         'CONDA_PROMPT_MODIFIER': '(c:\\users\\modza\\documents\\leetcode\\venv) ',
#         'CONDA_PYTHON_EXE': 'c:\\ProgramData\\miniconda3\\python.exe',
#         'CONDA_SHLVL': '2',
# ...

# %%
os.startfile('git.exe')

# %%
os.startfile('brave.exe')

# %%
path = r"C:\Program Files\Git\git-bash.exe"
os.system(path)
# Out:
# 1

# %%
git_bash_path = r"C:\Program Files\Git\git-bash.exe"
try:
    os.system(git_bash_path)
    print(f"Git Bash launched successfully from: {git_bash_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Git Bash launched successfully from: C:\Program Files\Git\git-bash.exe

# %%
r"C:\Program Files\Git" + "\tool"
# Out:
# 'C:\\Program Files\\Git\tool'

# %%
def os_control(tool: str):
        """
        please pass, tool(app) name and,
        its file holding the executable.

        
        """
    
        import os
        
        _path = r"C:\Program Files\Git"
        bash_path = os.path.join(_path,tool)
        
        try:
            # Execute the Git Bash executable
            os.system(f'"{bash_path}"') 
            print(f"Git Bash launched successfully from: {bash_path}")
        
        except Exception as e:
            print(f"An error occurred: {e}")

# %%
help(os_control)
# Out:
# Help on function os_control in module __main__:
#
# os_control(tool: str)
#     please pass, tool(app) name and,
#     its file holding the executable.

# %%
os_control('git-bash.exe')
# Out:
# Git Bash launched successfully from: C:\Program Files\Git\git-bash.exe

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'baby_products_sellers.csv',
#  'bash_sc.py',
#  'dataset_crawler-google-places_2025-12-09_07-49-09-261.csv',
#  'file_handling.ipynb',
#  'leetcode_pr',
#  'new.txt',
#  'new_dir_sub',
#  'regex_demo.ipynb',
#  'regex_pr.py',
#  'sha256sum.txt',
#  'Untitled.ipynb',
#  'venv']

# %%
with open('new.txt') as _f:
    print(_f.readline())
# Out:
# this is a new test file related to OS module use case along with other techniques

# %%
with open('sha256sum.txt') as _f:
    print(_f.read(), end =' ---- ')
# Out:
# 759c9b5a2ad26eb9844b24f7da1696c705ff5fe07924a749f385f435176c2306 *linuxmint-22.2-cinnamon-64bit.iso
# 21f5a5f7be652c60b20ba7996328098b14e979b1ef8bf7f6c9d4a2a579504a65 *linuxmint-22.2-mate-64bit.iso
# dea13e523dca28e3aa48d90167a6368c63e1b3251492115417fdbf648551558f *linuxmint-22.2-xfce-64bit.iso
#  ----

# %%
with open('sha256sum.txt') as _f:
    for line in _f:
        print(line)
# Out:
# 759c9b5a2ad26eb9844b24f7da1696c705ff5fe07924a749f385f435176c2306 *linuxmint-22.2-cinnamon-64bit.iso
#
# 21f5a5f7be652c60b20ba7996328098b14e979b1ef8bf7f6c9d4a2a579504a65 *linuxmint-22.2-mate-64bit.iso
#
# dea13e523dca28e3aa48d90167a6368c63e1b3251492115417fdbf648551558f *linuxmint-22.2-xfce-64bit.iso

# %%
path = r"C:\users\modza\documents"
direct = "leetcode"


os.path.join(path,direct)
# Out:
# 'C:\\users\\modza\\documents\\leetcode'

# %%
 os.getcwd()
# Out:
# 'C:\\Users\\modza\\Documents\\leetcode'

# %%
os.curdir
# Out:
# '.'

# %%
def os_control(tool: str):
        """
        please pass, tool(app) name and,
        its file holding the executable.

        
        """
    
        import os
        
        _path = r"C:\Program Files"
        bash_path = os.path.join(_path,tool)
        
        try:
            # Execute the Git Bash executable
            os.system(f'"{bash_path}"') 
            print(f"Git Bash launched successfully from: {bash_path}")
        
        except Exception as e:
            print(f"An error occurred: {e}")

# %%
os_control('MySQL\MySQL Workbench 8.0\mysqlworkbench.exe')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\modza\AppData\Local\Temp\ipykernel_7740\2311760660.py:1: SyntaxWarning: invalid escape sequence '\M'
#   os_control('MySQL\MySQL Workbench 8.0\mysqlworkbench.exe')
# Git Bash launched successfully from: C:\Program Files\MySQL\MySQL Workbench 8.0\mysqlworkbench.exe

# %%
os_control('Git\git-bash.exe')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\modza\AppData\Local\Temp\ipykernel_7740\855859037.py:1: SyntaxWarning: invalid escape sequence '\g'
#   os_control('Git\git-bash.exe')
# Git Bash launched successfully from: C:\Program Files\Git\git-bash.exe

# %%
os_control('Docker\Docker\docker desktop.exe')
# Out:
# Git Bash launched successfully from: C:\Program Files\Docker\Docker\docker desktop.exe
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\modza\AppData\Local\Temp\ipykernel_7740\586625377.py:1: SyntaxWarning: invalid escape sequence '\D'
#   os_control('Docker\Docker\docker desktop.exe')

# %%
 C:\Program Files\MySQL\MySQL Workbench 8.0
