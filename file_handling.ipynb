# %%
import os

# %%
print(os.getenv('HOME'))
# Out:
# None

# %%
os.getcwd()
# Out:
# 'C:\\Users\\modza\\Documents\\leetcode'

# %%
os.get_exec_path()
# Out:
# ['c:\\users\\modza\\documents\\leetcode\\venv',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\mingw-w64\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\usr\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Library\\bin',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\Scripts',
#  'c:\\users\\modza\\documents\\leetcode\\venv\\bin',
#  'c:\\ProgramData\\miniconda3\\condabin',
#  'C:\\Program Files\\Microsoft SDKs\\Azure\\CLI2\\wbin',
#  'C:\\Program Files\\FFmpeg\\bin',
#  'C:\\Program Files\\eSpeak NG',
#  'C:\\Users\\modza\\AppData\\Roaming\\python\\Python39\\Scripts',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\bin',
#  'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.1\\libnvvp',
#  'c:\\Users\\modza\\AppData\\Local\\Programs\\cursor\\resources\\app\\bin',
#  'C:\\Windows\\system32',
#  'C:\\Windows',
#  'C:\\Windows\\System32\\Wbem',
#  'C:\\Windows\\System32\\WindowsPowerShell\\v1.0',
# ...

# %%
os.process_cpu_count()
# Out:
# 8

# %%
os.getpid()
# Out:
# 7740

# %%
os.getlogin()
# Out:
# 'modza'

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  '.venv',
#  'bash_sc.py',
#  'file_handling.py',
#  'leetcode_pr',
#  'regex_pr.py',
#  'Untitled.ipynb',
#  'venv']

# %%
os.remove(file_handling.py)

# %%
import os
import pandas as pd

# %%
os.open("c:\\users\\modza\\downloads\\dataset_crawler-google-places_2025-12-09_07-49-09-261", flags =)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os.open("c:\\users\\modza\\downloads\\dataset_crawler-google-places_2025-12-09_07-49-09-261")
#
# TypeError: open() missing required argument 'flags' (pos 2)

# %%
df =pd.read_csv("c:\\users\\modza\\downloads\\dataset_crawler-google-places_2025-12-09_07-49-09-261.csv")

# %%
df.head()
# Out:
#                                              address           categoryName  \
# 0  Mahavir Nagar, Kandivali West, Mumbai, Maharas...             Baby store
# 1  metro station On, New Link Rd, Kandivali, Prag...             Baby store
# 2  Shop No 2, Bindiya Society, Ramdas Nayak Marg,...             Baby store
# 3  Shop No 4, Ahimsa Marg, off New Link Road, Mal...             Baby store
# 4  Yogi Prabhat bldg, D/8, 91, Yogi Nagar, Boriva...  Surgical supply store
#
#              phone  postalCode  reviewsCount        state  \
# 0  +91 97694 07640    400067.0            43  Maharashtra
# 1  +91 93244 26042    400067.0           651  Maharashtra
# 2  +91 91671 66166    400050.0            45  Maharashtra
# 3  +91 70459 22618    400064.0            48  Maharashtra
# 4  +91 90821 95552    400091.0            68  Maharashtra
#
#                                  title                            website
# 0                        Baby boutique  http://www.babyboutiqemumbai.com/
# ...

# %%
df.categoryName.value_counts().head(6)
# Out:
# categoryName
# Baby store                   342
# Clothing store                77
# Baby clothing store           75
# Children's clothing store     70
# Toy store                     33
# Children's store               9
# Name: count, dtype: int64

# %%
new_df = df[df.categoryName.isin(['Baby store','Baby clothing store',"Children's clothing store", 
                          'Toy store', "Children's store"])].sort_values(by = 'categoryName', ascending = True)

# %%
new_df.to_csv("baby_products_sellers.csv")

# %% [markdown]
# %run ./bash_and_sh.ipynb
