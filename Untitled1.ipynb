# %% [markdown]
# ###  Bash -ClI
#
# script --
#      > shebang command : #1 usr/bin/env /python3
#      >chmod +x script
#
#
# Config files + variables:
#
#     > .bashrc --all terminals  : very helpful to create shortcuts using alias and running directly from CLI
#                                : export API Keys
#
#     > search
#             -- find >realtime   ; if we are ging for exhaustive data , then we should stick with find
#             -- locate >speed    ; for speed, we should use locate.

# %% [markdown]
# ####
# * Linux shell,
# * bash script,
# * shebang
# * environment variables
# * alias

# %% [markdown]
# ####
# #!/bin/bash
#
# echo "Hello wrld"
#
# export my_var="Some_val"
#
# echo $my_var
#
# alias ll="ls -l"
#
# ll
